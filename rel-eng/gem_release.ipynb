# %% [markdown]
# ## Release of hammer-cli gem
#
# ### Requirements
# - push access to https://github.com/theforeman/hammer-cli
# - push access to rubygems.org for hammer-cli
# - sudo yum install transifex-client python-slugify asciidoc
# - ensure neither the `git push` or `gem push` don't require interractive auth. If you can't use api key or ssh key to auth skip these steps and run them form the shell manually
# - to push translations you need an account on Transifex (https://docs.transifex.com/client/client-configuration#~/-transifexrc)
#
# ### Release process
# - Follow the steps with `<Shift>+<Enter>` or `<Ctrl>+<Enter>,<Down>`
# - If anything fails, fix it and re-run the step if applicable
#
# ### Release settings

# %%
# %cd ..
# Out:
# /home/ogajduse/repos/hammer-cli

# %% [markdown]
# ### Update the following notebook settings

# %%
NEW_VERSION = '3.19.0'
LAST_VERSION = '3.18.0'
DEVELOP_VERSION = '3.20.0-develop'
NEXT_FUTURE_VERSION = '3.20.0'
MAJOR_RELEASE = True
STABLE_BRANCH = '3.19-stable'
GIT_REMOTE_UPSTREAM = 'upstream'
WORK_BRANCH = 'master' if MAJOR_RELEASE else STABLE_BRANCH
CHERRY_PICKS = []

# %% [markdown]
# ### Ensure the repo is up to date

# %%
! git checkout {WORK_BRANCH}
# Out:
# M	rel-eng/gem_release.ipynb
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %%
! git fetch {GIT_REMOTE_UPSTREAM}

# %%
! git rebase {GIT_REMOTE_UPSTREAM}/{WORK_BRANCH}
# Out:
# Current branch master is up to date.

# %% [markdown]
# ### Cherry picks for minor release

# %%
if not MAJOR_RELEASE:
    for cp in CHERRY_PICKS:
        ! git cherry-pick -x {cp}

# %% [markdown]
# ### Run tests localy

# %%
! bundle update
# Out:
# Fetching gem metadata from https://rubygems.org/...........
# Resolving dependencies....
# Using rake 13.4.2
# WARN: Unresolved or ambiguous specs during Gem::Specification.reset:
#       erb (>= 0)
#       Available/installed versions of this gem:
#       - 4.0.4
#       - 2.2.0
#       tsort (>= 0)
#       Available/installed versions of this gem:
#       - 0.2.0
#       - 0.1.0
# WARN: Clearing out unresolved specs. Try 'gem cleanup <gem>'
# Please report a bug if this causes problems.
# Using amazing_print 1.7.2
# Using ffi 1.17.4
# Using logger 1.7.0
# Using netrc 0.11.0
# Using forwardable 1.4.0
# Using singleton 0.3.0
# Using fiddle 1.1.8
# Using racc 1.8.1
# Using text 1.3.1
# Using io-console 0.8.2
# Using little-plugger 1.1.4
# Using multi_json 1.19.1
# Using csv 3.3.5
# Using domain_name 0.6.20240107
# Using minitest-spec-context 0.0.5
# Fetching mime-types-data 3.2026.0414
# Using ruby2_keywords 0.0.5
# Using docile 1.4.1
# Using thor 1.5.0
# Using minitest 5.26.1
# Fetching clamp 1.5.2
# Using erubi 1.13.1
# Using base64 0.3.0
# Using version_gem 1.1.9
# Using locale 2.1.5
# Using unicode-emoji 4.2.0
# Using simplecov-html 0.13.2
# Fetching mocha 3.1.0
# Using builder 3.3.0
# Using simplecov_json_formatter 0.1.4
# Using rexml 3.4.4
# Using gssapi 1.3.1
# Using hashie 5.1.0
# Using ci_reporter 2.1.0
# Using prime 0.1.4
# Using http-accept 1.7.0
# Using reline 0.6.3
# Using fast_gettext 4.0.0
# Using highline 3.1.2
# Using oauth-tty 1.0.6
# Using unicode-display_width 3.2.0
# Using simplecov 0.22.0
# Using ci_reporter_minitest 1.0.0
# Using logging 2.4.0
# Using snaky_hash 2.0.3
# Using gettext 3.5.2
# Fetching http-cookie 1.1.6
# Using bundler 2.2.33
# Using oauth 1.1.3
# Installing clamp 1.5.2
# Installing http-cookie 1.1.6
# Installing mocha 3.1.0
# Installing mime-types-data 3.2026.0414
# Using mime-types 3.7.0
# Using rest-client 2.1.0
# Using apipie-bindings 0.7.1
# Using hammer_cli 3.19.0.pre.develop from source at `.` and installing its executables
# Bundle updated!

# %%
! bundle exec rake test
# Out:
# /home/ogajduse/.rbenv/versions/3.0.7/bin/ruby -I"lib:lib" /home/ogajduse/.rbenv/versions/3.0.7/lib/ruby/gems/3.0.0/gems/rake-13.4.2/lib/rake/rake_test_loader.rb "test/functional/defaults_test.rb" "test/functional/help_test.rb" "test/functional/nil_values_test.rb" "test/unit/abstract_test.rb" "test/unit/apipie/api_connection_test.rb" "test/unit/apipie/command_test.rb" "test/unit/apipie/option_builder_test.rb" "test/unit/apipie/option_definition_test.rb" "test/unit/bash_test.rb" "test/unit/ca_cert_manager_test.rb" "test/unit/command_extensions_test.rb" "test/unit/completer_test.rb" "test/unit/connection_test.rb" "test/unit/csv_parser_test.rb" "test/unit/defaults_test.rb" "test/unit/exception_handler_test.rb" "test/unit/help/builder_test.rb" "test/unit/help/definition/abstract_item_test.rb" "test/unit/help/definition/list_test.rb" "test/unit/help/definition/note_test.rb" "test/unit/help/definition/section_test.rb" "test/unit/help/definition/text_test.rb" "test/unit/help/definition_test.rb" "test/unit/help/text_builder_test.rb" "test/unit/history_test.rb" "test/unit/i18n_test.rb" "test/unit/logger_test.rb" "test/unit/main_test.rb" "test/unit/messages_test.rb" "test/unit/modules_test.rb" "test/unit/option_builder_test.rb" "test/unit/options/matcher_test.rb" "test/unit/options/normalizers_test.rb" "test/unit/options/option_collector_test.rb" "test/unit/options/option_definition_test.rb" "test/unit/options/option_family_test.rb" "test/unit/options/processor_list_test.rb" "test/unit/options/sources/command_line_test.rb" "test/unit/options/sources/saved_defaults_test.rb" "test/unit/options/validators/dsl_test.rb" "test/unit/output/adapter/abstract_test.rb" "test/unit/output/adapter/base_test.rb" "test/unit/output/adapter/csv_test.rb" "test/unit/output/adapter/json_test.rb" "test/unit/output/adapter/table_test.rb" "test/unit/output/adapter/yaml_test.rb" "test/unit/output/definition_test.rb" "test/unit/output/dsl_test.rb" "test/unit/output/field_filter_test.rb" "test/unit/output/fields_test.rb" "test/unit/output/formatters_test.rb" "test/unit/output/output_test.rb" "test/unit/output/record_collection_test.rb" "test/unit/settings_test.rb" "test/unit/utils_test.rb" -v
# No permissions to create log dir /var/log/hammer.
# File /var/log/hammer/hammer.log not writeable, won't log anything to the file!
# Run options: -v --seed 12084
#
# # Running:
#
# Logging::LogEvent::#initialize_logger#test_0001_prints message to stderr when log dir can't be created = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0007_considers open single quotes with spaces incomplete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0003_considers open double quotes incomplete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0004_considers open double quotes with spaces incomplete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0001_considers a word without quotes complete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0002_considers a word without quotes ending with space incomplete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0005_considers closed double quotes complete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0008_considers closed single quotes complete = 0.00 s = .
# HammerCLI::CompleterWord::complete?#test_0006_considers open single quotes incomplete = 0.00 s = .
# HammerCLI::Output::MetaData#test_0001_converts numeric metadata to numbers = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOptionConstraint::#rejected#test_0001_returns nil when the option is missing = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOptionConstraint::#rejected#test_0002_raises exception when the option is present = 0.00 s = .
# HammerCLI::AbstractCommand::add_validators#test_0001_is called upon the option_collector initialization = 0.00 s = .
# HammerCLI::AbstractCommand::add_validators#test_0003_allows for creating inheritable validators = 0.00 s = .
# HammerCLI::AbstractCommand::add_validators#test_0002_inserts validators = 0.00 s = .
# HammerCLI::Defaults::#add_defaults_to_conf#test_0003_Should update dashed default when underscored default is set = 0.00 s = .
# HammerCLI::Defaults::#add_defaults_to_conf#test_0001_Should add a default param to defaults file, without a provider = 0.00 s = .
# HammerCLI::Defaults::#add_defaults_to_conf#test_0004_Should add a default param to defaults file, with provider = 0.00 s = .
# HammerCLI::Defaults::#add_defaults_to_conf#test_0002_adds values from hammer shell = 0.00 s = .
# HammerCLI::Options::OptionCollector::#options#test_0001_returns options without nil values but with NIL values = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0004_should set enum normalizer and handle coded values = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0001_should set array normalizer = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0002_should set boolean normalizer = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0003_should set enum normalizer = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0005_should set list normalizer for array of nested elements = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0007_should set number normalizer for integer = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting correct normalizers#test_0006_should set number normalizer = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0004_should recongize complete line that ends with quotes followed by space = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0009_should recongize empty line as complete = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0003_should recongize complete line that ends with quotes = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0008_should recongize one double quote as incomplete = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0001_should recongize incomplete line = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0002_should recongize complete line = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0007_should recongize one quote followed by space as incomplete = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0005_should recongize complete line that ends with double quotes = 0.00 s = .
# HammerCLI::CompleterLine::line complete#test_0006_should recongize one quote as incomplete = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle ids#test_0001_should ommit column of type Id by default = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle ids#test_0002_should print column of type Id when --show-ids is set = 0.00 s = .
# String::camelize#test_0001_should camelize string with underscores = 0.00 s = .
# String::camelize#test_0002_should not camelize string with dashes = 0.00 s = .
# HammerCLI::Options::Normalizers::abstract#test_0001_should raise exception on format = 0.00 s = .
# HammerCLI::Options::Normalizers::enum#test_0003_should rise argument error when the value is not in the list = 0.00 s = .
# HammerCLI::Options::Normalizers::enum#test_0001_should return return value when in the list = 0.00 s = .
# HammerCLI::Options::Normalizers::enum#test_0004_should list allowed values in description = 0.00 s = .
# HammerCLI::Options::Normalizers::enum#test_0002_should rise argument error when the value is nil = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract#test_0004_should keep compatible formatters = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract#test_0001_should have features = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract#test_0002_allows default pagination = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract#test_0003_should filter formatters with incompatible features = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract#test_0005_should put serializers first = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract#test_0006_should raise not implemented on print_collection = 0.00 s = .
# HammerCLI::Options::OptionDefinition::context#test_0001_should save option to context = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0018_should parse explicit strings = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0005_should parse a comma separated string with spaces using double quotes = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0004_should parse a comma separated string with spaces using single quotes = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0003_should parse a comma separated string with spaces = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0014_should parse empty array = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0008_should parse arrays = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0017_should parse a comma separated string 2 = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0007_should deal with equal sign in value = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0012_should parse arrays with spaces = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0010_should parse arrays with spaces using by single quotes = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0016_should parse empty hash = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0011_should parse arrays with spaces using by double quotes = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0001_should parse values with commas = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0009_should parse arrays with spaces = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0002_should parse a comma separated string = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0015_should parse hash with one item = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0013_should parse array with one item = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::key=value format#test_0006_should deal with equal sign in string value = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::print_message#test_0001_should print message with nil params = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::error messages#test_0003_should print string details of error to stderr = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::error messages#test_0001_should print error message to stderr = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::error messages#test_0004_should print formatted message with parameters = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::error messages#test_0002_should print list details of error to stderr = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::print_message#test_0001_should print message with nil params = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0004_should extend params only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0009_should extend option family only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0003_should extend help only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0008_should extend data only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0001_should extend options only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0002_should extend output only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0007_should extend params and options and headers = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0005_should extend headers only = 0.00 s = .
# HammerCLI::CommandExtensions::only#test_0006_should extend options only = 0.00 s = .
# HammerCLI::Help::Builder::adding an option with lower case description#test_0001_capitalizes the description = 0.00 s = .
# HammerCLI::Output::Dsl::fields#test_0003_should store all field details = 0.00 s = .
# HammerCLI::Output::Dsl::fields#test_0001_should create Field as default field type = 0.00 s = .
# HammerCLI::Output::Dsl::fields#test_0004_can define multiple fields = 0.00 s = .
# HammerCLI::Output::Dsl::fields#test_0002_should create field of desired type = 0.00 s = .
# HammerCLI::Output::Dsl#test_0001_should be empty after initialization = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::list#test_0004_handles multiple lines in the second column via definition = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::list#test_0001_prints empty list via definition = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::list#test_0002_prints single column list = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::list#test_0003_prints two column list via definition = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::list#test_0005_can adjust indentation of the second column via definition = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::printing by chunks#test_0003_prints another chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::printing by chunks#test_0001_prints single chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::printing by chunks#test_0004_prints last chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::printing by chunks#test_0002_prints first chunk = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::aliasing resources#test_0001_renames options = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::aliasing resources#test_0003_keeps option accessor the same = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::aliasing resources#test_0002_renames option types = 0.00 s = .
# HammerCLI::Output::Output::verbosity::quiet#test_0004_should not print error messages with higher verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::quiet#test_0001_should not print info messages with higher verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::quiet#test_0002_should print message with lower or equal verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::quiet#test_0003_should print error message even when hammer verbosity is level 0 = 0.00 s = .
# HammerCLI::Output::Output::verbosity::quiet#test_0005_should not print record data = 0.00 s = .
# HammerCLI::Output::Output::verbosity::quiet#test_0006_should not print collection data = 0.00 s = .
# HammerCLI::MainCommand::loading context::verbose#test_0001_stores verbosity level into context = 0.00 s = .
# String::underscore#test_0001_converts camelized string to underscore = 0.00 s = .
# String::underscore#test_0003_converts dashes to underscores = 0.00 s = .
# String::underscore#test_0002_converts full class path name to underscore with slashes = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::handle ids#test_0003_should print column of type Id when --show-ids is set = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::handle ids#test_0001_should ommit column of type Id by default = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::handle ids#test_0004_should print column of type ID when --show-ids is set but no data = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::handle ids#test_0002_should ommit column of type Id by default but no data = 0.00 s = .
# HammerCLI::Apipie::Command::resource defined#test_0001_should perform a call to api when resource is defined = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle fields with containers#test_0001_should print column names = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle fields with containers#test_0002_should print data = 0.00 s = .
# HammerCLI::ShellHistory::saving history#test_0003_appends to readline's history = 0.00 s = .
# HammerCLI::ShellHistory::saving history#test_0001_creates history file if it does not exist = 0.00 s = .
# HammerCLI::ShellHistory::saving history#test_0004_doesn't save exit command = 0.00 s = .
# HammerCLI::ShellHistory::saving history#test_0002_appends history to the given file = 0.00 s = .
# HammerCLI::Output::Definition::empty?#test_0001_returns true for empty definition = 0.00 s = .
# HammerCLI::Output::Definition::empty?#test_0002_returns false for definition with fields = 0.00 s = .
# HammerCLI::Modules::find by name#test_0001_must return nil if the module does not exist = 0.00 s = .
# HammerCLI::Modules::find by name#test_0003_must find the module with capital CLI in it's name = 0.00 s = .
# HammerCLI::Modules::find by name#test_0002_must must find the module = 0.00 s = .
# HammerCLI::Modules::names#test_0001_must return list of modules = 0.00 s = .
# HammerCLI::Modules::names#test_0002_must return empty array by default = 0.00 s = .
# message formatting#test_0007_test messages of HammerCLI::FullHelpCommand = 0.00 s = .
# message formatting#test_0003_test messages of HammerCLI::DefaultsCommand::ProvidersDefaultsCommand = 0.00 s = .
# message formatting#test_0004_test messages of HammerCLI::DefaultsCommand::ListDefaultsCommand = 0.00 s = .
# message formatting#test_0001_test messages of HammerCLI::DefaultsCommand = 0.00 s = .
# message formatting#test_0002_test messages of HammerCLI::DefaultsCommand::AddDefaultsCommand = 0.00 s = .
# message formatting#test_0005_test messages of HammerCLI::DefaultsCommand::DeleteDefaultsCommand = 0.00 s = .
# message formatting#test_0008_test messages of HammerCLI::Bash::PrebuildCompletionCommand = 0.00 s = .
# message formatting#test_0006_test messages of HammerCLI::ShellCommand = 0.00 s = .
# HammerCLI::Help::AbstractItem::#indent#test_0001_indents text = 0.00 s = .
# HammerCLI::Help::AbstractItem::#indent#test_0002_indents text with custom padding = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0005_should print labeled fields = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0004_should field with nested data = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0003_aligns multiple fields = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0007_should print unnumbered collection = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0013_should warn about deprecated fields = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0010_does not print fields which data are missing from api by default = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0008_hides ids by default = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0011_prints fields which data are missing from api when field has hide_missing flag set to false = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0012_should print key -> value = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0001_should print one field = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0009_skips blank values = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0002_doesn't print label when it's nil = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0006_should print collection = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection#test_0014_should warn about replaced fields = 0.00 s = .
# HammerCLI::MainCommand::loading context::username#test_0001_should prioritize parameter = 0.00 s = .
# HammerCLI::MainCommand::loading context::username#test_0002_should prioritize parameter 2 = 0.00 s = .
# HammerCLI::Output::Dsl::custom fields#test_0001_it creates field of a desired type = 0.00 s = .
# HammerCLI::Output::Dsl::custom fields#test_0002_passes all options to the field instance = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with one simple param#test_0004_should set description with html tags stripped = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with one simple param#test_0001_should create an option for the parameter = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with one simple param#test_0002_should set correct switch = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with one simple param#test_0003_should set correct attribute name = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with one simple param#test_0005_should build option with default family = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with one simple param#test_0006_should build parent option within default family = 0.00 s = .
# HammerCLI::Output::Definition::insert::after#test_0004_should accept block with new fields = 0.00 s = .
# HammerCLI::Output::Definition::insert::after#test_0001_should not insert field if output definition is empty = 0.00 s = .
# HammerCLI::Output::Definition::insert::after#test_0002_should insert new specified field after the old one = 0.00 s = .
# HammerCLI::Output::Definition::insert::after#test_0003_should insert after field with few new specified = 0.00 s = .
# HammerCLI::Output::Definition::insert::after#test_0005_should accept both block and new fields = 0.00 s = .
# HammerCLI::Output::Definition::insert::after#test_0006_should work with labels = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::printing by chunks#test_0003_prints another chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::printing by chunks#test_0001_prints single chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::printing by chunks#test_0004_prints last chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::printing by chunks#test_0002_prints first chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::show ids#test_0001_shows ids if it's required in the context = 0.00 s = .
# HammerCLI::Output::Adapter::Base#test_0001_allows default pagination = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::exist?#test_0001_throws not implemented error = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::hidden parameters#test_0001_should skip options for params with show? false = 0.00 s = .
# HammerCLI::Output::MetaData::pagination_set?#test_0001_can tell if pagination data are set = 0.00 s = .
# HammerCLI::Output::MetaData::pagination_set?#test_0002_can tell if pagination data are not set = 0.00 s = .
# HammerCLI::Options::OptionCollector::#all_options_raw#test_0001_returns all options with NIL values untranslated = 0.00 s = .
# HammerCLI::Options::OptionCollector::#all_options_raw#test_0002_can process validations = 0.00 s = .
# HammerCLI::Completer::command completion#test_0004_should filter by first two letters = 0.00 s = .
# HammerCLI::Completer::command completion#test_0008_should offer all available subcommands and options even if an egual sign option has been passed = 0.00 s = .
# HammerCLI::Completer::command completion#test_0007_should offer all available subcommands and options even if an option has been passed = 0.00 s = .
# HammerCLI::Completer::command completion#test_0005_should offer all available subcommands and options = 0.00 s = .
# HammerCLI::Completer::command completion#test_0011_should offer all available subcommands and options when quoted value with equal sign was passed = 0.00 s = .
# HammerCLI::Completer::command completion#test_0010_should offer all available subcommands and options when double quoted value was passed = 0.00 s = .
# HammerCLI::Completer::command completion#test_0003_should filter by first letter = 0.00 s = .
# HammerCLI::Completer::command completion#test_0001_should offer all available commands = 0.00 s = .
# HammerCLI::Completer::command completion#test_0009_should offer all available subcommands and options when quoted value was passed = 0.00 s = .
# HammerCLI::Completer::command completion#test_0002_should offer nothing when the line does not match = 0.00 s = .
# HammerCLI::Completer::command completion#test_0006_should offer all available subcommands and options even if a flag has been passed = 0.00 s = .
# Fields::Field::display?::blank is allowed#test_0001_returns false the value is nil = 0.00 s = .
# Fields::Field::display?::blank is allowed#test_0002_returns true when there is some data under the path = 0.00 s = .
# HammerCLI::AbstractCommand::defaults#test_0003_prefers values from command line = 0.00 s = .
# HammerCLI::AbstractCommand::defaults#test_0001_provides default value for an option flag = 0.00 s = .
# HammerCLI::AbstractCommand::defaults#test_0004_iterates over multiple switches of an option = 0.00 s = .
# HammerCLI::AbstractCommand::defaults#test_0002_does not set default value if the defaults are disabled = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::section#test_0001_prints section heading via definition = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::section#test_0002_indents section content via definition = 0.00 s = .
# HammerCLI::constant_path#test_0003_returns single constant = 0.00 s = .
# HammerCLI::constant_path#test_0001_returns empty array for empty string = 0.00 s = .
# HammerCLI::constant_path#test_0004_returns correct path for namespaced constant = 0.00 s = .
# HammerCLI::constant_path#test_0002_raises NameError for unknown constant = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0004_parses a dquoted string = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0008_should parse a comma separated string with quotes = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0007_parses a string with escaped comma = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0005_parses a quoted string = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0011_raises quoting error = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0010_parses a comma separated string with values including comma (dquotes) = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0003_parses single value = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0001_parses nil = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0009_parses a comma separated string with values including comma = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0002_parses empty string = 0.00 s = .
# HammerCLI::CSVParser::parse#test_0006_should parse a comma separated string = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues#test_0001_forbids default pagination = 0.00 s = .
# HammerCLI::Output::Definition#test_0001_should be able to add field = 0.00 s = .
# HammerCLI::Output::Definition#test_0003_clear should delete all fields = 0.00 s = .
# HammerCLI::Output::Definition#test_0002_append should allow to add data from another definition = 0.00 s = .
# HammerCLI::Help::TextBuilder::#insert::before#test_0001_should insert new help item before the old one = 0.00 s = .
# HammerCLI::Help::TextBuilder::#insert::before#test_0003_should work with labels = 0.00 s = .
# HammerCLI::Help::TextBuilder::#insert::before#test_0002_should insert multiple items before old item = 0.00 s = .
# HammerCLI::Apipie::Command::unsupported commands#test_0001_should print help for unsupported command = 0.00 s = .
# commands::defaults add#test_0007_reports unknown provider = 0.01 s = .
# commands::defaults add#test_0003_adds default from provider with name with dashed = 0.01 s = .
# commands::defaults add#test_0004_reports unsupported option = 0.00 s = .
# commands::defaults add#test_0001_adds static default = 0.00 s = .
# commands::defaults add#test_0002_adds default from provider = 0.00 s = .
# commands::defaults add#test_0005_reports missing parameter name = 0.00 s = .
# commands::defaults add#test_0008_reports IO errors = 0.00 s = .
# commands::defaults add#test_0006_reports missing parameter value or source = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOptionConstraint::#value#test_0001_returns value of the option = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOptionConstraint::#value#test_0002_returns nil when the option is missing = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list#test_0001_should return empty array on nil = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list#test_0003_should parse a string = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list#test_0002_should return empty array on empty string = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0004_should accept and parse YYYY-MM-DD HH:MM:SS = 0.01 s = .
# HammerCLI::Options::Normalizers::datetime#test_0009_should overwrite default timezone = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0003_should accept and parse iso8601 = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0008_should use system provided timezone = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0001_should raise argument error when the value is nil = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0002_should raise argument error when the value is not a date = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0007_should not parse non iso8601 formatted timezones = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0005_should accept and parse YYYY/MM/DD HH:MM:SS = 0.00 s = .
# HammerCLI::Options::Normalizers::datetime#test_0006_should parse iso8601 compliant timezones = 0.00 s = .
# HammerCLI::CompleterWord::quoted?#test_0001_returns false for an unquoted word = 0.00 s = .
# HammerCLI::CompleterWord::quoted?#test_0003_returns true for single quotes = 0.00 s = .
# HammerCLI::CompleterWord::quoted?#test_0002_returns true for double quotes = 0.00 s = .
# HammerCLI::Apipie::OptionDefinition::Option Description should be converted#test_0001_should be converted = 0.00 s = .
# String::indent#test_0001_indents single line string = 0.00 s = .
# String::indent#test_0002_indents multi line string = 0.00 s = .
# HammerCLI::Connection::#drop_all#test_0001_drops all connections = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0005_should handle usage error = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0004_should handle help request = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0010_should print simple prompts for even more nested arguments = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0008_should print default prompts for standard missing arguments = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0012_should print default prompts for standard missing arguments = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0007_should log the error = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0011_should print simple prompts for even more different nested arguments = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0003_should handle unknown exception = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0001_should handle unauthorized = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0009_should print right prompts for nested missing arguments = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0002_should handle general exception = 0.00 s = .
# HammerCLI::ExceptionHandler#test_0006_should handle resource not found = 0.00 s = .
# HammerCLI::AbstractCommand::#extend_with#test_0001_should extend command with option, output, help right away = 0.00 s = .
# HammerCLI::AbstractCommand::#extend_with#test_0002_should store more than one extension = 0.00 s = .
# HammerCLI::AbstractCommand::exception handler#test_0001_should return instance of hammer cli exception handler by default = 0.00 s = .
# HammerCLI::AbstractCommand::exception handler#test_0003_should return instance of exception handler class defined deeper in a module hierrarchy = 0.00 s = .
# HammerCLI::AbstractCommand::exception handler#test_0002_should return instance of exception handler class defined in a module = 0.00 s = .
# HammerCLI::Output::Output::messages#test_0004_prints error message via adapter with arguments = 0.00 s = .
# HammerCLI::Output::Output::messages#test_0001_prints info message via adapter = 0.00 s = .
# HammerCLI::Output::Output::messages#test_0002_prints info message via adapter with arguments = 0.00 s = .
# HammerCLI::Output::Output::messages#test_0003_prints error message via adapter = 0.00 s = .
# HammerCLI::Output::Output::messages#test_0005_prints error message with details via adapter = 0.00 s = .
# HammerCLI::Output::Output::messages#test_0006_prints error message from exception via adapter = 0.00 s = .
# HammerCLI::Options::Normalizers::default#test_0003_has empty description = 0.00 s = .
# HammerCLI::Options::Normalizers::default#test_0001_should not change any value = 0.00 s = .
# HammerCLI::Options::Normalizers::default#test_0004_has empty completion = 0.00 s = .
# HammerCLI::Options::Normalizers::default#test_0002_should not change nil value = 0.00 s = .
# HammerCLI::Output::Formatters::DateFormatter#test_0001_formats the date = 0.00 s = .
# HammerCLI::Output::Formatters::DateFormatter#test_0002_returns empty string on wrong value = 0.00 s = .
# HammerCLI::Output::Formatters::FormatterContainer#test_0001_accepts formatter = 0.00 s = .
# HammerCLI::Output::Formatters::FormatterContainer#test_0003_can add formatter to instance = 0.00 s = .
# HammerCLI::Output::Formatters::FormatterContainer#test_0002_has format method = 0.00 s = .
# HammerCLI::Apipie::Command::verbosity#test_0001_should print quiet messages only when hammer verbosity level is V_QUIET = 0.00 s = .
# HammerCLI::Apipie::Command::verbosity#test_0003_should print quiet + no-verbose + verbose messages only when hammer verbosity level is V_VERBOSE = 0.00 s = .
# HammerCLI::Apipie::Command::verbosity#test_0002_should print quiet + no-verbose messages only when hammer verbosity level is V_UNIX = 0.00 s = .
# HammerCLI::AbstractCommand::subcommand behavior::remove_subcommand#test_0001_should remove the subcommand = 0.00 s = .
# HammerCLI::AbstractCommand::subcommand behavior::remove_subcommand#test_0002_should write a message to log when removing subcommand = 0.00 s = .
# HammerCLI::Output::Output::data#test_0003_prints array of resources = 0.00 s = .
# HammerCLI::Output::Output::data#test_0001_prints single resource = 0.00 s = .
# HammerCLI::Output::Output::data#test_0004_prints recordset = 0.00 s = .
# HammerCLI::Output::Output::data#test_0002_prints single resource as collection = 0.00 s = .
# HammerCLI::Output::Adapter::Table#test_0001_allows default pagination = 0.00 s = .
# HammerCLI::Output::Adapter::Json#test_0001_forbids default pagination = 0.00 s = .
# HammerCLI::Defaults::#delete_default_from_conf::dashed#test_0001_Should remove default param from defaults file = 0.00 s = .
# HammerCLI::Defaults::#delete_default_from_conf::dashed#test_0002_Should remove dashed default param from defaults file = 0.00 s = .
# HammerCLI::Connection::#drop#test_0001_drops the connection = 0.00 s = .
# HammerCLI::insert_relative#test_0003_inserts after index = 0.00 s = .
# HammerCLI::insert_relative#test_0001_appends = 0.00 s = .
# HammerCLI::insert_relative#test_0004_inserts before index = 0.00 s = .
# HammerCLI::insert_relative#test_0002_prepends = 0.00 s = .
# HammerCLI::Options::Normalizers::json input#test_0003_should return a hash on valid json string = 0.00 s = .
# HammerCLI::Options::Normalizers::json input#test_0001_should return a hash on valid json file = 0.00 s = .
# HammerCLI::Options::Normalizers::json input#test_0004_should raise exception on invalid json string = 0.00 s = .
# HammerCLI::Options::Normalizers::json input#test_0002_should raise exception on invalid json file contents = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::output_stream#test_0001_should not print to stdout when --output-file is set = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::output_stream#test_0002_should print to file if --output-file is set = 0.00 s = .
# HammerCLI::Apipie::Command::options#test_0001_should collect method options from given options = 0.00 s = .
# HammerCLI::Apipie::Command::options#test_0002_should collect method options from methods = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::printing by chunks#test_0003_prints another chunk = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::printing by chunks#test_0001_prints single chunk = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::printing by chunks#test_0004_prints last chunk = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::printing by chunks#test_0002_prints first chunk = 0.00 s = .
# HammerCLI::Options::Matcher#test_0004_tests multiple values or regexes = 0.00 s = .
# HammerCLI::Options::Matcher#test_0001_tests value = 0.00 s = .
# HammerCLI::Options::Matcher#test_0002_tests regex = 0.00 s = .
# HammerCLI::Options::Matcher#test_0003_tests multiple conditions = 0.00 s = .
# HammerCLI::Options::Matcher#test_0005_tests nil for unknown methods = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_collection::show ids#test_0001_shows ids if it's required in the context = 0.00 s = .
# HammerCLI::Options::OptionFamily::switch#test_0001_returns nil if family is empty = 0.00 s = .
# HammerCLI::Options::OptionFamily::switch#test_0003_returns switch based on members = 0.00 s = .
# HammerCLI::Options::OptionFamily::switch#test_0002_returns parent switch if family has no children = 0.00 s = .
# HammerCLI::Options::Sources::CommandLine::#get_options#test_0001_reads options from the command = 0.00 s = .
# HammerCLI::Options::Sources::CommandLine::#get_options#test_0002_keeps options that are already set = 0.00 s = .
# HammerCLI::Defaults::#get_defaults::dashed params#test_0001_should get the default param, without provider = 0.00 s = .
# HammerCLI::Defaults::#get_defaults::dashed params#test_0002_should get the default param, with provider = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::required#test_0001_should raise exception when exist? returns true = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::required#test_0003_should return nil when exist? returns true = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::required#test_0002_should raise exception with a message = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::AllConstraint::exist?#test_0001_should return true when no options are passed = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::AllConstraint::exist?#test_0003_should return false when one of the options is missing = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::AllConstraint::exist?#test_0002_should return true when all the options exist = 0.00 s = .
# HammerCLI::CompleterWord::quote#test_0003_recognizes double quotes = 0.00 s = .
# HammerCLI::CompleterWord::quote#test_0001_returns empty string for empty word = 0.00 s = .
# HammerCLI::CompleterWord::quote#test_0004_recognizes single quotes = 0.00 s = .
# HammerCLI::CompleterWord::quote#test_0002_returns empty string for word without quotes = 0.00 s = .
# Logging::LogEvent::filtering#test_0001_can filter log data = 0.00 s = .
# HammerCLI::Output::Formatters::FormatterLibrary#test_0001_accepts formatter = 0.00 s = .
# HammerCLI::Output::Formatters::FormatterLibrary#test_0002_can add formatter to instance = 0.00 s = .
# HammerCLI::AbstractCommand::validate_options#test_0001_adds a validation block = 0.00 s = .
# HammerCLI::AbstractCommand::validate_options#test_0003_allows relative inserts of custom validators = 0.00 s = .
# HammerCLI::AbstractCommand::validate_options#test_0002_allows for multiple validation blocks = 0.00 s = .
# HammerCLI::Output::Dsl::collection#test_0001_creates field of type Collection = 0.00 s = .
# HammerCLI::Output::Dsl::collection#test_0003_sets correct path to subfields = 0.00 s = .
# HammerCLI::Output::Dsl::collection#test_0002_allows to define subfields with dsl = 0.00 s = .
# HammerCLI::AbstractCommand::option builder#test_0001_uses builder container as default = 0.00 s = .
# HammerCLI::AbstractCommand::option builder#test_0002_Default builder container is empty = 0.00 s = .
# HammerCLI::Options::ProcessorList::#name#test_0001_returns the given name = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_collection::printing by chunks#test_0003_prints another chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_collection::printing by chunks#test_0001_prints single chunk = 0.01 s = .
# HammerCLI::Output::Adapter::Yaml::print_collection::printing by chunks#test_0004_prints last chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_collection::printing by chunks#test_0002_prints first chunk = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint::#required#test_0001_returns nil when one of the options exist = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint::#required#test_0003_raises exception when more than one of the options is present = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint::#required#test_0002_raises exception when none of the options is present = 0.00 s = .
# commands::defaults list#test_0001_prints all defaults = 0.01 s = .
# commands::defaults list#test_0002_prints empty defaults = 0.00 s = .
# HammerCLI::Help::Definition::#find_item#test_0001_finds an item = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle fields with collections#test_0001_should print collection column name = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle fields with collections#test_0003_should handle empty collection = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection::handle fields with collections#test_0002_should print collection data = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::output_stream#test_0001_should not print to stdout when --output-file is set = 0.00 s = .
# HammerCLI::Output::Adapter::Base::print_collection::output_stream#test_0002_should print to file if --output-file is set = 0.00 s = .
# String::constantize#test_0003_returns correct constant = 0.00 s = .
# String::constantize#test_0001_raises NameError for empty string = 0.00 s = .
# String::constantize#test_0004_returns correct namespaced constant = 0.00 s = .
# String::constantize#test_0002_raises NameError for unknown constant = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::pagination#test_0001_should print pagination info if data are not complete = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::pagination#test_0002_should print pagination info if data are complete = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::show ids#test_0001_shows ids if it's required in the context = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml#test_0001_forbids default pagination = 0.00 s = .
# HammerCLI::Output::RecordCollection#test_0001_should keep records and its meta data = 0.00 s = .
# HammerCLI::Output::RecordCollection#test_0003_sould accept MetaData as option = 0.00 s = .
# HammerCLI::Output::RecordCollection#test_0002_should wrap the data into list = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint::#exist?#test_0001_should return true when one of the options exist = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint::#exist?#test_0003_should return false when more than one of the options is present = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint::#exist?#test_0002_should return false when the option isn't present = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::OneOfConstraint#test_0001_raises exception when nothing to check is set = 0.00 s = .
# HammerCLI::Apipie::OptionDefinition::referenced resource#test_0001_should be nil by default = 0.00 s = .
# HammerCLI::Apipie::OptionDefinition::referenced resource#test_0003_should convert referenced resource name to string = 0.00 s = .
# HammerCLI::Apipie::OptionDefinition::referenced resource#test_0002_should set referenced resource = 0.00 s = .
# HammerCLI::Help::Definition::#insert_definition::after#test_0001_should insert new help item after the old one = 0.00 s = .
# HammerCLI::Help::Definition::#insert_definition::after#test_0003_should work with labels = 0.00 s = .
# HammerCLI::Help::Definition::#insert_definition::after#test_0002_should insert multiple items after old item = 0.00 s = .
# HammerCLI::Output::Dsl::label#test_0001_creates field of type Label = 0.00 s = .
# HammerCLI::Output::Dsl::label#test_0003_sets correct path to subfields = 0.00 s = .
# HammerCLI::Output::Dsl::label#test_0002_allows to define subfields with dsl = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::setting referenced resources#test_0001_sets referenced resources = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::formatters#test_0001_should apply formatters = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::formatters#test_0002_should not break formatting = 0.00 s = .
# HammerCLI::Apipie::ApiConnection::#initialize::with :clear_cache => true#test_0001_clears cache = 0.00 s = .
# HammerCLI::Apipie::ApiConnection::#initialize::with :clear_cache => true#test_0002_logs message when logger is available = 0.00 s = .
# HammerCLI::Help::TextBuilder::#insert::after#test_0001_should insert new help item after the old one = 0.00 s = .
# HammerCLI::Help::TextBuilder::#insert::after#test_0003_should work with labels = 0.00 s = .
# HammerCLI::Help::TextBuilder::#insert::after#test_0002_should insert multiple items after old item = 0.00 s = .
# HammerCLI::Defaults::#delete_default_from_conf#test_0001_Should remove default param from defaults file = 0.00 s = .
# HammerCLI::Defaults::#delete_default_from_conf#test_0002_Should remove dashed default param from defaults file = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::rejected#test_0001_should raise exception when exist? returns true = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::rejected#test_0003_should return nil when exist? returns true = 0.00 s = .
# constraints::HammerCLI::Options::Validators::DSL::BaseConstraint::rejected#test_0002_should raise exception with a message = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_message#test_0001_prints the message = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_message#test_0003_prints the message with nil params = 0.00 s = .
# HammerCLI::Output::Adapter::Yaml::print_message#test_0002_prints the message with name and id = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::required options#test_0001_should set required flag for the required options = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::required options#test_0002_should not require any option when requirements are disabled = 0.00 s = .
# HammerCLI::Help::Section::#build_string#test_0001_builds string without definition = 0.00 s = .
# HammerCLI::Help::Section::#build_string#test_0002_builds string with definition = 0.00 s = .
# HammerCLI::Options::Sources::SavedDefaults::#get_options#test_0001_logs message about loaded default value = 0.00 s = .
# HammerCLI::Options::Sources::SavedDefaults::#get_options#test_0003_keeps options that are already set = 0.00 s = .
# HammerCLI::Options::Sources::SavedDefaults::#get_options#test_0002_reads values for all switches = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::text#test_0001_prints text via definition = 0.00 s = .
# HammerCLI::Help::Definition::#build_string::text#test_0002_prints multiple blocks with spaces via definition = 0.00 s = .
# Fields::ContainerField::display?::blank is allowed#test_0003_returns false the value is empty hash = 0.00 s = .
# Fields::ContainerField::display?::blank is allowed#test_0001_returns false the value is nil = 0.00 s = .
# Fields::ContainerField::display?::blank is allowed#test_0004_returns true when there is some data under the path = 0.00 s = .
# Fields::ContainerField::display?::blank is allowed#test_0002_returns false the value is empty array = 0.00 s = .
# HammerCLI::CACertManager::#cert_file_name#test_0001_make file name from host uri = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection#test_0003_does not print fields which data are missing from api by default = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection#test_0001_should print column name = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection#test_0004_prints fields which data are missing from api when field has hide_missing flag set to false = 0.00 s = .
# HammerCLI::Output::Adapter::CSValues::print_collection#test_0002_should print field value = 0.00 s = .
# ...
# HammerCLI::Options::OptionDefinition::deprecated options#test_0006_shows multiple flag specific depracated messages in help = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0007_censors passwords from the debug logs = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0003_should have logger that accepts custom name = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0004_should have logger that can inspect object = 0.01 s = .
# HammerCLI::AbstractCommand::logging#test_0001_should log what has been executed = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0002_should have logger named by the class by default = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0005_should have logger.watch output without colors = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0008_password parameters should be hidden in logs = 0.00 s = .
# HammerCLI::AbstractCommand::logging#test_0006_should have logger.watch colorized output switch in settings = 0.00 s = .
# Fields::Field::parameters#test_0001_returns all parameters passed to a filed = 0.00 s = .
# HammerCLI::Output::Formatters::InlineTextFormatter#test_0001_prints multiline text to one line = 0.00 s = .
# HammerCLI::Output::Formatters::InlineTextFormatter#test_0002_accepts nil = 0.00 s = .
# HammerCLI::Output::Output::verbosity::no-verbose#test_0004_should not print error messages with higher verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::no-verbose#test_0001_should not print info messages with higher verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::no-verbose#test_0002_should print message with lower or equal verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::no-verbose#test_0003_should print error message = 0.00 s = .
# HammerCLI::Output::Output::verbosity::no-verbose#test_0005_should print record data = 0.00 s = .
# HammerCLI::Output::Output::verbosity::no-verbose#test_0006_should print collection data = 0.00 s = .
# Fields::Field::display?::blank is not allowed#test_0001_returns false the value is nil = 0.00 s = .
# Fields::Field::display?::blank is not allowed#test_0002_returns true when there is some data under the path = 0.00 s = .
# HammerCLI::Options::Normalizers::number#test_0001_should return number on numeric values = 0.00 s = .
# HammerCLI::Options::Normalizers::number#test_0002_should raise ArgumentError on non-numeric values = 0.00 s = .
# HammerCLI::Settings#test_0005_finds nested settings = 0.00 s = .
# HammerCLI::Settings#test_0004_takes both strings and symbols = 0.00 s = .
# HammerCLI::Settings#test_0010_clear wipes all settings but default values = 0.00 s = .
# HammerCLI::Settings#test_0008_merges hash settings on second load = 0.00 s = .
# HammerCLI::Settings#test_0012_initializes settings with default settings = 0.00 s = .
# HammerCLI::Settings#test_0007_dumps all settings = 0.00 s = .
# HammerCLI::Settings#test_0011_empty wipes all settings including default values = 0.00 s = .
# HammerCLI::Settings#test_0003_returns correct value = 0.00 s = .
# HammerCLI::Settings#test_0001_returns nil when nothing is loaded = 0.00 s = .
# HammerCLI::Settings#test_0009_merges array settings on second load = 0.00 s = .
# HammerCLI::Settings#test_0002_returns nil on unknown key = 0.00 s = .
# HammerCLI::Settings#test_0006_loads all settings = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0004_should split when last character is equal sign = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0008_should split line with single quotes and space between = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0007_should split line with double quotes = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0005_should split on equal sign when quotes are used = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0011_should split line with one double quote and space between = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0010_should split line with double quotes and space between = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0003_should split on equal sign = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0001_should split basic line = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0009_should split line with one single quote and space between = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0002_should split basic line with space at the end = 0.00 s = .
# HammerCLI::CompleterLine::splitting words#test_0006_should split line with single quotes = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0005_should return true on 1 = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0004_should return true on y = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0010_should return false on 0 = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0008_should return false on no = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0012_should raise exception on other values = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0007_should return false on f = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0011_should raise exception on nil = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0003_should return true on yes = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0001_should return true on true = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0009_should return false on n = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0002_should return true on t = 0.00 s = .
# HammerCLI::Options::Normalizers::bool#test_0006_should return false on false = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::printing by chunks#test_0003_prints another chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::printing by chunks#test_0001_prints single chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::printing by chunks#test_0004_prints last chunk = 0.00 s = .
# HammerCLI::Output::Adapter::Table::print_collection::printing by chunks#test_0002_prints first chunk = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0004_returns options when subcommand is given = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0008_return no options for option-value pair without complete value = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0007_return hint for option-value pair without value = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0005_returns no options when subcommand is wrong = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0011_allows subcommand after options = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0010_allows mutiple options with values of the same subcommand = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0003_returns filtered options when partial input is given = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0001_returns options when no input given = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0009_allows mutiple options of the same subcommand = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0002_returns filtered options when partial input is given = 0.00 s = .
# HammerCLI::Bash::Completion::#complete#test_0006_returns no options when there are no other params allowed = 0.00 s = .
# HammerCLI::Output::Formatters::BooleanFormatter#test_0001_says yes for true like objects = 0.00 s = .
# HammerCLI::Output::Formatters::BooleanFormatter#test_0002_says no for false, nil, empty string and 0 = 0.00 s = .
# HammerCLI::Defaults::#get_defaults#test_0001_should get the default param = 0.00 s = .
# HammerCLI::Defaults::#get_defaults#test_0003_should get the default param, with provider = 0.00 s = .
# HammerCLI::Defaults::#get_defaults#test_0002_should get the default param for short flag = 0.00 s = .
# Fields::Label::display?::blank is not allowed#test_0004_returns false when the value is empty hash = 0.00 s = .
# Fields::Label::display?::blank is not allowed#test_0001_returns true when all subfields are displayed = 0.00 s = .
# Fields::Label::display?::blank is not allowed#test_0002_returns true when at least one or the subfields is displayed = 0.00 s = .
# Fields::Label::display?::blank is not allowed#test_0003_returns false when none of the subfieldsis displayed = 0.00 s = .
# Fields::Label::display?::blank is not allowed#test_0005_returns false when the value is nil = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::filtering options#test_0003_should skip single filtered option in array = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::filtering options#test_0001_should skip filtered options = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::filtering options#test_0004_should skip single filtered option = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::filtering options#test_0002_should skip filtered options defined as symbols = 0.00 s = .
# HammerCLI::Completer::option value completion#test_0004_should complete quoted option values = 0.00 s = .
# HammerCLI::Completer::option value completion#test_0001_should complete option values = 0.00 s = .
# HammerCLI::Completer::option value completion#test_0002_should complete option values when equal sign is used = 0.00 s = .
# HammerCLI::Completer::option value completion#test_0003_should complete option values = 0.00 s = .
# HammerCLI::Completer::option value completion#test_0005_should complete quoted option values = 0.00 s = .
# HammerCLI::Help::TextBuilder::#at#test_0001_should return self if path is empty = 0.00 s = .
# HammerCLI::Help::TextBuilder::#at#test_0003_should work with labels = 0.00 s = .
# HammerCLI::Help::TextBuilder::#at#test_0002_should return definition of specified help item with path = 0.00 s = .
# HammerCLI::Settings::load from paths#test_0003_store config path history = 0.00 s = .
# HammerCLI::Settings::load from paths#test_0001_loads settings from file = 0.00 s = .
# HammerCLI::Settings::load from paths#test_0004_loads settings from dir = 0.00 s = .
# HammerCLI::Settings::load from paths#test_0002_clears path history on clear invokation = 0.00 s = .
# HammerCLI::AbstractCommand::subcommand behavior::subcommand!#test_0001_should replace commands with the same name = 0.00 s = .
# HammerCLI::AbstractCommand::subcommand behavior::subcommand!#test_0003_should add the subcommand = 0.00 s = .
# HammerCLI::AbstractCommand::subcommand behavior::subcommand!#test_0002_should write a message to log when replacing subcommand = 0.00 s = .
# String::formatting#test_0004_should replace named parameters with string keys = 0.00 s = .
# String::formatting#test_0001_should not fail without expected parameters = 0.00 s = .
# String::formatting#test_0002_should replace positional parameters = 0.00 s = .
# String::formatting#test_0003_should replace named parameters = 0.00 s = .
# String::formatting#test_0005_should replace named parameters marked with curly brackets = 0.00 s = .
# String::formatting#test_0007_should consider false values = 0.00 s = .
# String::formatting#test_0006_should not fail due to presence of percent chars in string = 0.00 s = .
# HammerCLI::Help::Definition::#insert_definition::before#test_0001_should insert new help item before the old one = 0.00 s = .
# HammerCLI::Help::Definition::#insert_definition::before#test_0003_should work with labels = 0.00 s = .
# HammerCLI::Help::Definition::#insert_definition::before#test_0002_should insert multiple items before old item = 0.00 s = .
# HammerCLI::Options::ProcessorList::#insert_relative#test_0004_inserts before = 0.00 s = .
# HammerCLI::Options::ProcessorList::#insert_relative#test_0001_appends = 0.00 s = .
# HammerCLI::Options::ProcessorList::#insert_relative#test_0002_prepends = 0.00 s = .
# HammerCLI::Options::ProcessorList::#insert_relative#test_0003_inserts after = 0.00 s = .
# HammerCLI::Options::ProcessorList::#insert_relative#test_0005_raises an exception when the processor was not found = 0.00 s = .
# HammerCLI::Output::Output::verbosity::verbose#test_0004_should not print error messages with higher verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::verbose#test_0001_should not print info messages with higher verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::verbose#test_0002_should print message with lower or equal verbosity level = 0.00 s = .
# HammerCLI::Output::Output::verbosity::verbose#test_0003_should print error message = 0.00 s = .
# HammerCLI::Output::Output::verbosity::verbose#test_0005_should print record data = 0.00 s = .
# HammerCLI::Output::Output::verbosity::verbose#test_0006_should print collection data = 0.00 s = .
# HammerCLI::Completer::subcommand completion#test_0004_should ignore options specified before the last command = 0.00 s = .
# HammerCLI::Completer::subcommand completion#test_0001_should filter subcommands by first letter = 0.00 s = .
# HammerCLI::Completer::subcommand completion#test_0002_should offer nothing when the line does not match any subcommand = 0.00 s = .
# HammerCLI::Completer::subcommand completion#test_0003_should ignore flags specified before the last command = 0.00 s = .
# HammerCLI::Completer::subcommand completion#test_0005_should ignore equal sign separated options specified before the last command = 0.00 s = .
# HammerCLI::Completer::subcommand completion#test_0006_should filter subcommands by first three letters = 0.00 s = .
# HammerCLI::Defaults::#add_defaults_to_conf::dashed#test_0001_Should update underscored default when dashed default is set = 0.00 s = .
# HammerCLI::Defaults::#add_defaults_to_conf::dashed#test_0002_should update underscored default with option syntax when dashed default is set = 0.00 s = .
# HammerCLI::Help::Builder::option family#test_0001_prints option families = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::test data_for_field#test_0003_returns DataMissing instance, if the data does not exist for the field = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::test data_for_field#test_0001_returns nil if the record is nil = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::test data_for_field#test_0004_returns the value, if data exists for the field = 0.00 s = .
# HammerCLI::Output::Adapter::Abstract::test data_for_field#test_0002_returns nil if the record is not a hash = 0.00 s = .
# HammerCLI::Output::Formatters::ListFormatter#test_0004_can put the string on a new line = 0.00 s = .
# HammerCLI::Output::Formatters::ListFormatter#test_0001_serializes the value = 0.00 s = .
# HammerCLI::Output::Formatters::ListFormatter#test_0002_returns empty string when the input is nil = 0.00 s = .
# HammerCLI::Output::Formatters::ListFormatter#test_0003_returns string value when the input is not a list = 0.00 s = .
# HammerCLI::Output::Formatters::ListFormatter#test_0005_allows to change the separator = 0.00 s = .
# HammerCLI::Output::Formatters::ListFormatter#test_0006_can format list vertically = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::json format#test_0001_parses arrays = 0.00 s = .
# HammerCLI::Options::Normalizers::key_value_list::json format#test_0002_parses objects = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::output_stream#test_0001_should not print to stdout when --output-file is set = 0.00 s = .
# HammerCLI::Output::Adapter::Json::print_collection::output_stream#test_0002_should print to file if --output-file is set = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with hash params#test_0001_should create options for all parameters except the hash = 0.00 s = .
# HammerCLI::Apipie::OptionBuilder::with hash params#test_0002_should name the options correctly = 0.00 s = .
# HammerCLI::Output::Output::formatters#test_0001_should register formatter = 0.00 s = .
# HammerCLI::Connection::#create#test_0001_creates new connection = 0.00 s = .
# HammerCLI::Connection::#create#test_0003_writes message to log = 0.00 s = .
# HammerCLI::Connection::#create#test_0002_doesn't overwrite the connection when called multiple times = 0.00 s = .
#
# Finished in 0.556826s, 1582.1809 runs/s, 2379.5570 assertions/s.
#
# 881 runs, 1325 assertions, 0 failures, 0 errors, 0 skips
# Coverage report generated for MiniTest to /home/ogajduse/repos/coverage.
# Line Coverage: 89.53% (3319 / 3707)

# %% [markdown]
# ### Update release related stuff

# %%
! pwd
# Out:
# /home/ogajduse/repos/hammer-cli

# %%
! sed -i 's/Gem::Version.new .*/Gem::Version.new "{NEW_VERSION}"/' lib/hammer_cli/version.rb

# %%
# Parse git changelog
from IPython.display import Markdown as md
from subprocess import check_output
from shlex import split
import re

def format_log_entry(entry):
    issues = re.findall(r'[^(]#([0-9]+)', entry)
    entry = re.sub(r'([fF]ixes|[rR]efs)[^-]*-\s*(.*)', r'\2', entry)
    entry = '* ' + entry.capitalize()
    entry = re.sub(r'\(#([0-9]+)\)', r'([PR #\1](https://github.com/theforeman/hammer-cli/pull/\1))', entry)
    for i in issues:
        referenced_issues.append(i)
        entry = entry + ', [#%s](http://projects.theforeman.org/issues/%s)' % (i, i)
    return entry

def skip(entry):
    if re.match(r'Merge pull', entry) or \
      re.match(r'^i18n', entry) or \
      re.match(r'^Bump to version', entry):
        return True
    else:
        return False
referenced_issues = []    
git_log_cmd = 'git log --pretty=format:"%%s" %s..HEAD' % LAST_VERSION
log = check_output(split(git_log_cmd)).decode('utf8').split('\n')
change_log = [format_log_entry(e) for e in log if not skip(e)]
md('\n'.join(change_log))
# Out:
# * Bump to 3.18.0-develop

# %%
# Write release notes
from datetime import datetime
import fileinput
import sys

fh = fileinput.input('doc/release_notes.md', inplace=True)  
for line in fh:  
    print(line.rstrip())
    if re.match(r'========', line):
        print('### %s (%s)' % (NEW_VERSION, datetime.today().strftime('%Y-%m-%d')))
        for entry in change_log:
            print(entry)
        print('')
fh.close()

# %% [markdown]
# #### Manual step: Update deps in the gemspec if neccessary

# %% [markdown]
# ### Check what is going to be commited

# %%
! git add -u
! git status

# %%
! git diff --cached

# %% [markdown]
# ### Commit changes

# %%
! git commit -m "Bump to {NEW_VERSION}"

# %% [markdown]
# ### Update translations

# %%
if MAJOR_RELEASE:
    ! bundle exec rake tx:update

# %% [markdown]
# ### Tag new version

# %%
! git tag {NEW_VERSION}

# %% [markdown]
# ### Prepare stable branch for major release

# %%
if MAJOR_RELEASE:
    ! git checkout -b {STABLE_BRANCH}
    ! git push {GIT_REMOTE_UPSTREAM} {STABLE_BRANCH}
    ! git checkout {WORK_BRANCH}

# %% [markdown]
# ### Build the gem

# %%
! rake build

# %%
! gem push pkg/hammer_cli-{NEW_VERSION}.gem

# %% [markdown]
# ### Bump the develop version for major release

# %%
if MAJOR_RELEASE:
    ! sed -i 's/Gem::Version.new .*/Gem::Version.new "{DEVELOP_VERSION}"/' lib/hammer_cli/version.rb

# %%
if MAJOR_RELEASE:
    ! git add -u
    ! git status

# %%
if MAJOR_RELEASE:
    ! git diff --cached

# %%
if MAJOR_RELEASE:
    ! git commit -m "Bump to {DEVELOP_VERSION}"

# %% [markdown]
# ### PUSH the changes upstream If everything is correct

# %%
! git push {GIT_REMOTE_UPSTREAM} {WORK_BRANCH}

# %%
! git push --tags {GIT_REMOTE_UPSTREAM} {WORK_BRANCH}

# %% [markdown]
# #### Now the new release is in upstream repo

# %% [markdown]
# ### Some manual steps follow to improve the UX
#
# #### New relase on GitHub
#
# Copy the following changelog lines to the description in form on link below
# The release title is the new version.

# %%
print('\n')
print('\n'.join(change_log))
print('\n\nhttps://github.com/theforeman/hammer-cli/releases/new?tag=%s' % NEW_VERSION)

# %%
from IPython.display import Markdown as md

md('### Create new hammer-cli release in Redmine \n' + \
    '<a href="https://projects.theforeman.org/projects/hammer-cli/versions/new" target="_blank">https://projects.theforeman.org/projects/hammer-cli/versions/new</a>\n\n' + \
    'Set name to hammer-cli-%s' % (NEXT_FUTURE_VERSION if MAJOR_RELEASE else NEW_VERSION))

# %%
if not MAJOR_RELEASE:
    print('Set fixed in versions to %s in following issues:' % NEW_VERSION)
    for i in referenced_issues:
        print('- https://projects.theforeman.org/issues/%s' % i)

# %% [markdown]
# ## Congratulations
#
# Release is public now. Please, don't forget to do packaging (https://github.com/theforeman/foreman-packaging).
