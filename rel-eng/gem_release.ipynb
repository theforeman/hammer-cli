# %% [markdown]
# ## Release of hammer-cli gem
#
# ### Requirements
# - push access to https://github.com/theforeman/hammer-cli
# - push access to rubygems.org for hammer-cli
# - sudo yum install transifex-client python-slugify asciidoc
# - ensure neither the `git push` or `gem push` don't require interractive auth. If you can't use api key or ssh key to auth skip these steps and run them form the shell manually
# - to push translations you need an account on Transifex (https://docs.transifex.com/client/client-configuration#~/-transifexrc)
#
# ### Release process
# - Follow the steps with `<Shift>+<Enter>` or `<Ctrl>+<Enter>,<Down>`
# - If anything fails, fix it and re-run the step if applicable
#
# ### Release settings

# %%
# %cd ..

# %% [markdown]
# ### Update the following notebook settings

# %%
NEW_VERSION = '3.18.0'
LAST_VERSION = '3.17.0'
DEVELOP_VERSION = '3.19.0-develop'
NEXT_FUTURE_VERSION = '3.19.0'
MAJOR_RELEASE = True
STABLE_BRANCH = '3.18-stable'
GIT_REMOTE_UPSTREAM = 'origin'
WORK_BRANCH = 'master' if MAJOR_RELEASE else STABLE_BRANCH
CHERRY_PICKS = []

# %% [markdown]
# ### Ensure the repo is up to date

# %%
! git checkout {WORK_BRANCH}
# Out:
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %%
! git fetch {GIT_REMOTE_UPSTREAM}

# %%
! git rebase {GIT_REMOTE_UPSTREAM}/{WORK_BRANCH}
# Out:
# Current branch master is up to date.

# %% [markdown]
# ### Cherry picks for minor release

# %%
if not MAJOR_RELEASE:
    for cp in CHERRY_PICKS:
        ! git cherry-pick -x {cp}

# %% [markdown]
# ### Run tests localy

# %%
! bundle update
# Out:
# Fetching gem metadata from https://rubygems.org/...........
# Resolving dependencies...
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/version.rb:8: warning: already initialized constant RDoc::VERSION
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/version.rb:8: warning: previous definition of VERSION was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:68: warning: already initialized constant RDoc::VISIBILITIES
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:68: warning: previous definition of VISIBILITIES was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:74: warning: already initialized constant RDoc::DOT_DOC_FILENAME
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:74: warning: previous definition of DOT_DOC_FILENAME was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:79: warning: already initialized constant RDoc::GENERAL_MODIFIERS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:79: warning: previous definition of GENERAL_MODIFIERS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:84: warning: already initialized constant RDoc::CLASS_MODIFIERS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:84: warning: previous definition of CLASS_MODIFIERS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:89: warning: already initialized constant RDoc::ATTR_MODIFIERS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:89: warning: previous definition of ATTR_MODIFIERS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:94: warning: already initialized constant RDoc::CONSTANT_MODIFIERS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:94: warning: previous definition of CONSTANT_MODIFIERS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc.rb:99: warning: already initialized constant RDoc::METHOD_MODIFIERS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc.rb:99: warning: previous definition of METHOD_MODIFIERS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown.rb:257: warning: already initialized constant RDoc::Markdown::KpegPosInfo
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown.rb:257: warning: previous definition of KpegPosInfo was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown/entities.rb:5: warning: already initialized constant RDoc::Markdown::HTML_ENTITIES
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown/entities.rb:5: warning: previous definition of HTML_ENTITIES was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown/literals.rb:86: warning: already initialized constant RDoc::Markdown::Literals::KpegPosInfo
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown/literals.rb:86: warning: previous definition of KpegPosInfo was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown/literals.rb:446: warning: already initialized constant RDoc::Markdown::Literals::Rules
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown/literals.rb:446: warning: previous definition of Rules was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown.rb:584: warning: already initialized constant RDoc::Markdown::EXTENSIONS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown.rb:584: warning: previous definition of EXTENSIONS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown.rb:589: warning: already initialized constant RDoc::Markdown::DEFAULT_EXTENSIONS
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown.rb:589: warning: previous definition of DEFAULT_EXTENSIONS was here
# /usr/share/gems/gems/rdoc-6.14.0/lib/rdoc/markdown.rb:16556: warning: already initialized constant RDoc::Markdown::Rules
# /home/evgeni/.gem/ruby/gems/rdoc-7.1.0/lib/rdoc/markdown.rb:16416: warning: previous definition of Rules was here
# Fetching amazing_print 2.0.0
# Fetching mime-types-data 3.2026.0203
# Fetching clamp 1.4.0
# Fetching minitest-spec-context 0.0.5
# Fetching ci_reporter 2.1.0
# Installing amazing_print 2.0.0
# Installing clamp 1.4.0
# Installing mime-types-data 3.2026.0203
# Installing minitest-spec-context 0.0.5
# Installing ci_reporter 2.1.0
# Fetching ci_reporter_minitest 1.0.0
# Fetching apipie-bindings 0.7.1
# Installing ci_reporter_minitest 1.0.0
# Installing apipie-bindings 0.7.1
# Bundle updated!
# 1 installed gem you directly depend on is looking for funding.
#   Run `bundle fund` for details

# %%
! bundle exec rake test
# Out:
# (in /home/evgeni/Devel/theforeman/hammer-cli)
# /usr/bin/ruby -I"lib:lib" /home/evgeni/.gem/ruby/gems/rake-13.3.1/lib/rake/rake_test_loader.rb "test/functional/defaults_test.rb" "test/functional/help_test.rb" "test/functional/nil_values_test.rb" "test/unit/abstract_test.rb" "test/unit/apipie/api_connection_test.rb" "test/unit/apipie/command_test.rb" "test/unit/apipie/option_builder_test.rb" "test/unit/apipie/option_definition_test.rb" "test/unit/bash_test.rb" "test/unit/ca_cert_manager_test.rb" "test/unit/command_extensions_test.rb" "test/unit/completer_test.rb" "test/unit/connection_test.rb" "test/unit/csv_parser_test.rb" "test/unit/defaults_test.rb" "test/unit/exception_handler_test.rb" "test/unit/help/builder_test.rb" "test/unit/help/definition/abstract_item_test.rb" "test/unit/help/definition/list_test.rb" "test/unit/help/definition/note_test.rb" "test/unit/help/definition/section_test.rb" "test/unit/help/definition/text_test.rb" "test/unit/help/definition_test.rb" "test/unit/help/text_builder_test.rb" "test/unit/history_test.rb" "test/unit/i18n_test.rb" "test/unit/logger_test.rb" "test/unit/main_test.rb" "test/unit/messages_test.rb" "test/unit/modules_test.rb" "test/unit/option_builder_test.rb" "test/unit/options/matcher_test.rb" "test/unit/options/normalizers_test.rb" "test/unit/options/option_collector_test.rb" "test/unit/options/option_definition_test.rb" "test/unit/options/option_family_test.rb" "test/unit/options/processor_list_test.rb" "test/unit/options/sources/command_line_test.rb" "test/unit/options/sources/saved_defaults_test.rb" "test/unit/options/validators/dsl_test.rb" "test/unit/output/adapter/abstract_test.rb" "test/unit/output/adapter/base_test.rb" "test/unit/output/adapter/csv_test.rb" "test/unit/output/adapter/json_test.rb" "test/unit/output/adapter/table_test.rb" "test/unit/output/adapter/yaml_test.rb" "test/unit/output/definition_test.rb" "test/unit/output/dsl_test.rb" "test/unit/output/field_filter_test.rb" "test/unit/output/fields_test.rb" "test/unit/output/formatters_test.rb" "test/unit/output/output_test.rb" "test/unit/output/record_collection_test.rb" "test/unit/settings_test.rb" "test/unit/utils_test.rb"
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging.rb:10: warning: syslog was loaded from the standard library, but is not part of the default gems starting from Ruby 3.4.0.
# You can add syslog to your Gemfile or gemspec to silence this warning.
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:166: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:417: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:389: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:398: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:166: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:417: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:389: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/.gem/ruby/gems/logging-2.4.0/lib/logging/layouts/pattern.rb:398: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# No permissions to create log dir /var/log/hammer.
# File /var/log/hammer/hammer.log not writeable, won't log anything to the file!
# Run options: --seed 34838
#
# # Running:
#
# ................................................................................................................................................................................................................................................................................................................................................................................................/home/evgeni/Devel/theforeman/hammer-cli/lib/hammer_cli/shell.rb:48: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# ./home/evgeni/Devel/theforeman/hammer-cli/lib/hammer_cli/shell.rb:48: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# /home/evgeni/Devel/theforeman/hammer-cli/lib/hammer_cli/shell.rb:48: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# ./home/evgeni/Devel/theforeman/hammer-cli/lib/hammer_cli/shell.rb:48: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# ./home/evgeni/Devel/theforeman/hammer-cli/lib/hammer_cli/shell.rb:48: warning: literal string will be frozen in the future (run with --debug-frozen-string-literal for more information)
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#
# Finished in 0.187139s, 4707.7307 runs/s, 7080.2987 assertions/s.
#
# 881 runs, 1325 assertions, 0 failures, 0 errors, 0 skips
# Coverage report generated for MiniTest to /home/evgeni/Devel/theforeman/coverage.
# Line Coverage: 89.53% (3319 / 3707)

# %% [markdown]
# ### Update release related stuff

# %%
! pwd
# Out:
# /home/evgeni/Devel/theforeman/hammer-cli/rel-eng

# %%
! cd .. && sed -i 's/Gem::Version.new .*/Gem::Version.new "{NEW_VERSION}"/' lib/hammer_cli/version.rb

# %%
# Parse git changelog
from IPython.display import Markdown as md
from subprocess import check_output
from shlex import split
import re

def format_log_entry(entry):
    issues = re.findall(r'[^(]#([0-9]+)', entry)
    entry = re.sub(r'([fF]ixes|[rR]efs)[^-]*-\s*(.*)', r'\2', entry)
    entry = '* ' + entry.capitalize()
    entry = re.sub(r'\(#([0-9]+)\)', r'([PR #\1](https://github.com/theforeman/hammer-cli/pull/\1))', entry)
    for i in issues:
        referenced_issues.append(i)
        entry = entry + ', [#%s](http://projects.theforeman.org/issues/%s)' % (i, i)
    return entry

def skip(entry):
    if re.match(r'Merge pull', entry) or \
      re.match(r'^i18n', entry) or \
      re.match(r'^Bump to version', entry):
        return True
    else:
        return False
referenced_issues = []    
git_log_cmd = 'git log --pretty=format:"%%s" %s..HEAD' % LAST_VERSION
log = check_output(split(git_log_cmd)).decode('utf8').split('\n')
change_log = [format_log_entry(e) for e in log if not skip(e)]
md('\n'.join(change_log))
# Out:
# * Bump to 3.18.0-develop

# %%
# Write release notes
from datetime import datetime
import fileinput
import sys

fh = fileinput.input('doc/release_notes.md', inplace=True)  
for line in fh:  
    print(line.rstrip())
    if re.match(r'========', line):
        print('### %s (%s)' % (NEW_VERSION, datetime.today().strftime('%Y-%m-%d')))
        for entry in change_log:
            print(entry)
        print('')
fh.close()

# %% [markdown]
# #### Manual step: Update deps in the gemspec if neccessary

# %% [markdown]
# ### Check what is going to be commited

# %%
! git add -u
! git status

# %%
! git diff --cached

# %% [markdown]
# ### Commit changes

# %%
! git commit -m "Bump to {NEW_VERSION}"

# %% [markdown]
# ### Update translations

# %%
if MAJOR_RELEASE:
    ! bundle exec rake tx:update

# %% [markdown]
# ### Tag new version

# %%
! git tag {NEW_VERSION}

# %% [markdown]
# ### Prepare stable branch for major release

# %%
if MAJOR_RELEASE:
    ! git checkout -b {STABLE_BRANCH}
    ! git push {GIT_REMOTE_UPSTREAM} {STABLE_BRANCH}
    ! git checkout {WORK_BRANCH}

# %% [markdown]
# ### Build the gem

# %%
! rake build

# %%
! gem push pkg/hammer_cli-{NEW_VERSION}.gem

# %% [markdown]
# ### Bump the develop version for major release

# %%
if MAJOR_RELEASE:
    ! sed -i 's/Gem::Version.new .*/Gem::Version.new "{DEVELOP_VERSION}"/' lib/hammer_cli/version.rb

# %%
if MAJOR_RELEASE:
    ! git add -u
    ! git status

# %%
if MAJOR_RELEASE:
    ! git diff --cached

# %%
if MAJOR_RELEASE:
    ! git commit -m "Bump to {DEVELOP_VERSION}"

# %% [markdown]
# ### PUSH the changes upstream If everything is correct

# %%
! git push {GIT_REMOTE_UPSTREAM} {WORK_BRANCH}

# %%
! git push --tags {GIT_REMOTE_UPSTREAM} {WORK_BRANCH}

# %% [markdown]
# #### Now the new release is in upstream repo

# %% [markdown]
# ### Some manual steps follow to improve the UX
#
# #### New relase on GitHub
#
# Copy the following changelog lines to the description in form on link below
# The release title is the new version.

# %%
print('\n')
print('\n'.join(change_log))
print('\n\nhttps://github.com/theforeman/hammer-cli/releases/new?tag=%s' % NEW_VERSION)

# %%
from IPython.display import Markdown as md

md('### Create new hammer-cli release in Redmine \n' + \
    '<a href="https://projects.theforeman.org/projects/hammer-cli/versions/new" target="_blank">https://projects.theforeman.org/projects/hammer-cli/versions/new</a>\n\n' + \
    'Set name to hammer-cli-%s' % (NEXT_FUTURE_VERSION if MAJOR_RELEASE else NEW_VERSION))

# %%
if not MAJOR_RELEASE:
    print('Set fixed in versions to %s in following issues:' % NEW_VERSION)
    for i in referenced_issues:
        print('- https://projects.theforeman.org/issues/%s' % i)

# %% [markdown]
# ## Congratulations
#
# Release is public now. Please, don't forget to do packaging (https://github.com/theforeman/foreman-packaging).
